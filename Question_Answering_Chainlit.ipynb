# %%
# !pip install transformers==4.41.2
# !pip install bitsandbytes==0.43.1
# !pip install accelerate==0.31.0
# !pip install langchain==0.2.5
# !pip install langchainhub==0.1.20
# !pip install langchain-chroma==0.1.1
# !pip install langchain-community==0.2.5
# !pip install langchain_huggingface==0.0.3
# !pip install python-dotenv==1.0.1
# !pip install pypdf==4.2.0
# !pip install numpy
# !pip install chainlit==1.1.304


# Install npm packages
# !npm install -g localtunnel
# !npm install -g npm
# Out:
# Requirement already satisfied: transformers==4.41.2 in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (0.23.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.41.2) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers==4.41.2) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.2) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.2) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.41.2) (2024.6.2)
# Collecting bitsandbytes==0.43.1
#   Downloading bitsandbytes-0.43.1-py3-none-manylinux_2_24_x86_64.whl (119.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 MB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.43.1) (2.3.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bitsandbytes==0.43.1) (1.25.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->bitsandbytes==0.43.1)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch->bitsandbytes==0.43.1) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->bitsandbytes==0.43.1)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->bitsandbytes==0.43.1) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->bitsandbytes==0.43.1) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bitsandbytes
# Successfully installed bitsandbytes-0.43.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105
# Collecting accelerate==0.31.0
#   Downloading accelerate-0.31.0-py3-none-any.whl (309 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.4/309.4 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate==0.31.0) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate==0.31.0) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate==0.31.0) (12.5.82)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.31.0) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate==0.31.0) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate==0.31.0) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate==0.31.0) (2024.6.2)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate==0.31.0) (1.3.0)
# Installing collected packages: accelerate
# Successfully installed accelerate-0.31.0
# Collecting langchain==0.2.5
#   Downloading langchain-0.2.5-py3-none-any.whl (974 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.6/974.6 kB 14.3 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (4.0.3)
# Collecting langchain-core<0.3.0,>=0.2.7 (from langchain==0.2.5)
#   Downloading langchain_core-0.2.11-py3-none-any.whl (337 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 kB 35.4 MB/s eta 0:00:00
# Collecting langchain-text-splitters<0.3.0,>=0.2.0 (from langchain==0.2.5)
#   Downloading langchain_text_splitters-0.2.2-py3-none-any.whl (25 kB)
# Collecting langsmith<0.2.0,>=0.1.17 (from langchain==0.2.5)
#   Downloading langsmith-0.1.83-py3-none-any.whl (127 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.5/127.5 kB 15.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (2.8.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain==0.2.5) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.2.5) (1.9.4)
# Collecting jsonpatch<2.0,>=1.33 (from langchain-core<0.3.0,>=0.2.7->langchain==0.2.5)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.7->langchain==0.2.5) (24.1)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.2.0,>=0.1.17->langchain==0.2.5)
#   Downloading orjson-3.10.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.1/141.1 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.2.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.2.5) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain==0.2.5) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.2.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.2.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.2.5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain==0.2.5) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.2.5) (3.0.3)
# Collecting jsonpointer>=1.9 (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain==0.2.5)
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Installing collected packages: orjson, jsonpointer, jsonpatch, langsmith, langchain-core, langchain-text-splitters, langchain
# Successfully installed jsonpatch-1.33 jsonpointer-3.0.0 langchain-0.2.5 langchain-core-0.2.11 langchain-text-splitters-0.2.2 langsmith-0.1.83 orjson-3.10.6
# Collecting langchainhub==0.1.20
#   Downloading langchainhub-0.1.20-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub==0.1.20) (24.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchainhub==0.1.20) (2.31.0)
# Collecting types-requests<3.0.0.0,>=2.31.0.2 (from langchainhub==0.1.20)
#   Downloading types_requests-2.32.0.20240622-py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub==0.1.20) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub==0.1.20) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub==0.1.20) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchainhub==0.1.20) (2024.6.2)
# Installing collected packages: types-requests, langchainhub
# Successfully installed langchainhub-0.1.20 types-requests-2.32.0.20240622
# Collecting langchain-chroma==0.1.1
#   Downloading langchain_chroma-0.1.1-py3-none-any.whl (8.5 kB)
# Collecting chromadb<0.6.0,>=0.4.0 (from langchain-chroma==0.1.1)
#   Downloading chromadb-0.5.3-py3-none-any.whl (559 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 16.8 MB/s eta 0:00:00
# Collecting fastapi<1,>=0.95.2 (from langchain-chroma==0.1.1)
#   Downloading fastapi-0.111.0-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<0.3,>=0.1.40 in /usr/local/lib/python3.10/dist-packages (from langchain-chroma==0.1.1) (0.2.11)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-chroma==0.1.1) (1.25.2)
# Requirement already satisfied: build>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.2.1)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.8.0)
# Collecting chroma-hnswlib==0.7.3 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading chroma_hnswlib-0.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 82.4 MB/s eta 0:00:00
# Collecting uvicorn[standard]>=0.18.3 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading uvicorn-0.30.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.9 MB/s eta 0:00:00
# Collecting posthog>=2.4.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading posthog-3.5.0-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading onnxruntime-1.18.1-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 93.7 MB/s eta 0:00:00
# Collecting opentelemetry-api>=1.2.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_api-1.25.0-py3-none-any.whl (59 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 10.6 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.25.0-py3-none-any.whl (18 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_instrumentation_fastapi-0.46b0-py3-none-any.whl (11 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_sdk-1.25.0-py3-none-any.whl (107 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 16.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.19.1)
# Collecting pypika>=0.48.9 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 10.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (4.66.4)
# Collecting overrides>=7.3.1 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (6.4.0)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.64.1)
# Collecting bcrypt>=4.0.1 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading bcrypt-4.1.3-cp39-abi3-manylinux_2_28_x86_64.whl (283 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 32.9 MB/s eta 0:00:00
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.12.3)
# Collecting kubernetes>=28.1.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading kubernetes-30.1.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 69.2 MB/s eta 0:00:00
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (8.4.2)
# Requirement already satisfied: PyYAML>=6.0.0 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (6.0.1)
# Collecting mmh3>=4.0.1 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading mmh3-4.1.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: orjson>=3.9.12 in /usr/local/lib/python3.10/dist-packages (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.10.6)
# Collecting httpx>=0.27.0 (from chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 11.3 MB/s eta 0:00:00
# Collecting starlette<0.38.0,>=0.37.2 (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1)
#   Downloading starlette-0.37.2-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 10.2 MB/s eta 0:00:00
# Collecting fastapi-cli>=0.0.2 (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1)
#   Downloading fastapi_cli-0.0.4-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: jinja2>=2.11.2 in /usr/local/lib/python3.10/dist-packages (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1) (3.1.4)
# Collecting python-multipart>=0.0.7 (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1)
#   Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Collecting ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1)
#   Downloading ujson-5.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 5.3 MB/s eta 0:00:00
# Collecting email_validator>=2.0.0 (from fastapi<1,>=0.95.2->langchain-chroma==0.1.1)
#   Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma==0.1.1) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma==0.1.1) (0.1.83)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.40->langchain-chroma==0.1.1) (24.1)
# Requirement already satisfied: pyproject_hooks in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.1.0)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from build>=1.0.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.0.1)
# Collecting dnspython>=2.0.0 (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain-chroma==0.1.1)
#   Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 22.8 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from email_validator>=2.0.0->fastapi<1,>=0.95.2->langchain-chroma==0.1.1) (3.7)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2024.6.2)
# Collecting httpcore==1.* (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 11.4 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.3.1)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.11.2->fastapi<1,>=0.95.2->langchain-chroma==0.1.1) (2.1.5)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3,>=0.1.40->langchain-chroma==0.1.1) (3.0.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.27.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/local/lib/python3.10/dist-packages (from kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.0.7)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (24.3.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.20.3)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.12.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting importlib-metadata<=7.1,>=6.0 (from opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading importlib_metadata-7.1.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.63.2)
# Collecting opentelemetry-exporter-otlp-proto-common==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.25.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-proto==1.25.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_proto-1.25.0-py3-none-any.whl (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 8.7 MB/s eta 0:00:00
# Collecting opentelemetry-instrumentation-asgi==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_instrumentation_asgi-0.46b0-py3-none-any.whl (14 kB)
# Collecting opentelemetry-instrumentation==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_instrumentation-0.46b0-py3-none-any.whl (29 kB)
# Collecting opentelemetry-semantic-conventions==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_semantic_conventions-0.46b0-py3-none-any.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.5/130.5 kB 20.5 MB/s eta 0:00:00
# Collecting opentelemetry-util-http==0.46b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading opentelemetry_util_http-0.46b0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.14.1)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.46b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading asgiref-3.8.1-py3-none-any.whl (23 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.28->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.3.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.23.4)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (13.7.1)
# Collecting httptools>=0.5.0 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading httptools-0.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 38.8 MB/s eta 0:00:00
# Collecting python-dotenv>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading uvloop-0.19.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 91.5 MB/s eta 0:00:00
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading watchfiles-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.3 MB/s eta 0:00:00
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading websockets-12.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (130 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.27.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.2.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (4.9)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2023.6.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api>=1.2.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.19.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (2.16.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.1 MB/s eta 0:00:00
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.6.0,>=0.4.0->langchain-chroma==0.1.1) (0.6.0)
# Building wheels for collected packages: pypika
#   Building wheel for pypika (pyproject.toml) ... done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53724 sha256=4f154b735a6d3bf4edd2d2014a11e5892cd17ba8dcf22a1c30cad228d1d8f91c
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built pypika
# Installing collected packages: pypika, monotonic, mmh3, websockets, uvloop, ujson, python-multipart, python-dotenv, overrides, opentelemetry-util-http, opentelemetry-proto, importlib-metadata, humanfriendly, httptools, h11, dnspython, deprecated, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, posthog, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, httpcore, email_validator, coloredlogs, opentelemetry-semantic-conventions, opentelemetry-instrumentation, onnxruntime, kubernetes, httpx, opentelemetry-sdk, opentelemetry-instrumentation-asgi, fastapi-cli, opentelemetry-instrumentation-fastapi, opentelemetry-exporter-otlp-proto-grpc, fastapi, chromadb, langchain-chroma
#   Attempting uninstall: importlib-metadata
#     Found existing installation: importlib_metadata 8.0.0
#     Uninstalling importlib_metadata-8.0.0:
#       Successfully uninstalled importlib_metadata-8.0.0
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.1.3 chroma-hnswlib-0.7.3 chromadb-0.5.3 coloredlogs-15.0.1 deprecated-1.2.14 dnspython-2.6.1 email_validator-2.2.0 fastapi-0.111.0 fastapi-cli-0.0.4 h11-0.14.0 httpcore-1.0.5 httptools-0.6.1 httpx-0.27.0 humanfriendly-10.0 importlib-metadata-7.1.0 kubernetes-30.1.0 langchain-chroma-0.1.1 mmh3-4.1.0 monotonic-1.6 onnxruntime-1.18.1 opentelemetry-api-1.25.0 opentelemetry-exporter-otlp-proto-common-1.25.0 opentelemetry-exporter-otlp-proto-grpc-1.25.0 opentelemetry-instrumentation-0.46b0 opentelemetry-instrumentation-asgi-0.46b0 opentelemetry-instrumentation-fastapi-0.46b0 opentelemetry-proto-1.25.0 opentelemetry-sdk-1.25.0 opentelemetry-semantic-conventions-0.46b0 opentelemetry-util-http-0.46b0 overrides-7.7.0 posthog-3.5.0 pypika-0.48.9 python-dotenv-1.0.1 python-multipart-0.0.9 starlette-0.37.2 ujson-5.10.0 uvicorn-0.30.1 uvloop-0.19.0 watchfiles-0.22.0 websockets-12.0
# Collecting langchain-community==0.2.5
#   Downloading langchain_community-0.2.5-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 24.8 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (3.9.5)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community==0.2.5)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: langchain<0.3.0,>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (0.2.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (0.2.11)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (0.1.83)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (1.25.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community==0.2.5) (8.4.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.5) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.5) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.5) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.5) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.5) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community==0.2.5) (4.0.3)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.5)
#   Downloading marshmallow-3.21.3-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.2/49.2 kB 7.4 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.5)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.5->langchain-community==0.2.5) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain<0.3.0,>=0.2.5->langchain-community==0.2.5) (2.8.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.7->langchain-community==0.2.5) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3.0,>=0.2.7->langchain-community==0.2.5) (24.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.0->langchain-community==0.2.5) (3.10.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community==0.2.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community==0.2.5) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community==0.2.5) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community==0.2.5) (2024.6.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.5) (4.12.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community==0.2.5) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.7->langchain-community==0.2.5) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.5->langchain-community==0.2.5) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.5->langchain-community==0.2.5) (2.20.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.2.5)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, marshmallow, typing-inspect, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 langchain-community-0.2.5 marshmallow-3.21.3 mypy-extensions-1.0.0 typing-inspect-0.9.0
# Collecting langchain_huggingface==0.0.3
#   Downloading langchain_huggingface-0.0.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface==0.0.3) (0.23.4)
# Requirement already satisfied: langchain-core<0.3,>=0.1.52 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface==0.0.3) (0.2.11)
# Collecting sentence-transformers>=2.6.0 (from langchain_huggingface==0.0.3)
#   Downloading sentence_transformers-3.0.1-py3-none-any.whl (227 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface==0.0.3) (0.19.1)
# Requirement already satisfied: transformers>=4.39.0 in /usr/local/lib/python3.10/dist-packages (from langchain_huggingface==0.0.3) (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.23.0->langchain_huggingface==0.0.3) (4.12.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface==0.0.3) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface==0.0.3) (0.1.83)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.3,>=0.1.52->langchain_huggingface==0.0.3) (2.8.0)
# ...
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (12.5.82)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=2.6.0->langchain_huggingface==0.0.3) (1.3.0)
# Installing collected packages: sentence-transformers, langchain_huggingface
# Successfully installed langchain_huggingface-0.0.3 sentence-transformers-3.0.1
# Requirement already satisfied: python-dotenv==1.0.1 in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Collecting pypdf==4.2.0
#   Downloading pypdf-4.2.0-py3-none-any.whl (290 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.4/290.4 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf==4.2.0) (4.12.2)
# Installing collected packages: pypdf
# Successfully installed pypdf-4.2.0
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.25.2)
# Collecting chainlit==1.1.304
#   Downloading chainlit-1.1.304-py3-none-any.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 54.5 MB/s eta 0:00:00
# Collecting aiofiles<24.0.0,>=23.1.0 (from chainlit==1.1.304)
#   Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting asyncer<0.0.3,>=0.0.2 (from chainlit==1.1.304)
#   Downloading asyncer-0.0.2-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (8.1.7)
# Collecting dataclasses_json<0.6.0,>=0.5.7 (from chainlit==1.1.304)
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Collecting fastapi<0.111.0,>=0.110.1 (from chainlit==1.1.304)
#   Downloading fastapi-0.110.3-py3-none-any.whl (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.8/91.8 kB 13.2 MB/s eta 0:00:00
# Collecting filetype<2.0.0,>=1.2.0 (from chainlit==1.1.304)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (0.27.0)
# Collecting lazify<0.5.0,>=0.4.0 (from chainlit==1.1.304)
#   Downloading Lazify-0.4.0-py2.py3-none-any.whl (3.1 kB)
# Collecting literalai==0.0.604 (from chainlit==1.1.304)
#   Downloading literalai-0.0.604.tar.gz (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 7.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (1.6.0)
# Collecting numpy<2.0,>=1.26 (from chainlit==1.1.304)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 74.6 MB/s eta 0:00:00
# Collecting packaging<24.0,>=23.1 (from chainlit==1.1.304)
#   Downloading packaging-23.2-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (2.8.0)
# Collecting pyjwt<3.0.0,>=2.8.0 (from chainlit==1.1.304)
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (1.0.1)
# Requirement already satisfied: python-multipart<0.0.10,>=0.0.9 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (0.0.9)
# Collecting python-socketio<6.0.0,>=5.11.0 (from chainlit==1.1.304)
#   Downloading python_socketio-5.11.3-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.2/76.2 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: starlette<0.38.0,>=0.37.2 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (0.37.2)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit==1.1.304)
#   Downloading syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tomli<3.0.0,>=2.0.1 in /usr/local/lib/python3.10/dist-packages (from chainlit==1.1.304) (2.0.1)
# Collecting uptrace<2.0.0,>=1.22.0 (from chainlit==1.1.304)
#   Downloading uptrace-1.24.0-py3-none-any.whl (8.6 kB)
# Collecting uvicorn<0.26.0,>=0.25.0 (from chainlit==1.1.304)
#   Downloading uvicorn-0.25.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.3/60.3 kB 8.9 MB/s eta 0:00:00
# Collecting watchfiles<0.21.0,>=0.20.0 (from chainlit==1.1.304)
#   Downloading watchfiles-0.20.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.8 MB/s eta 0:00:00
# Collecting chevron>=0.14.0 (from literalai==0.0.604->chainlit==1.1.304)
#   Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: anyio<4.0.0,>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from asyncer<0.0.3,>=0.0.2->chainlit==1.1.304) (3.7.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit==1.1.304) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses_json<0.6.0,>=0.5.7->chainlit==1.1.304) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from fastapi<0.111.0,>=0.110.1->chainlit==1.1.304) (4.12.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->chainlit==1.1.304) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->chainlit==1.1.304) (1.0.5)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->chainlit==1.1.304) (3.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.23.0->chainlit==1.1.304) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.23.0->chainlit==1.1.304) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->chainlit==1.1.304) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->chainlit==1.1.304) (2.20.0)
# Requirement already satisfied: bidict>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from python-socketio<6.0.0,>=5.11.0->chainlit==1.1.304) (0.23.1)
# Collecting python-engineio>=4.8.0 (from python-socketio<6.0.0,>=5.11.0->chainlit==1.1.304)
#   Downloading python_engineio-4.9.1-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: opentelemetry-api~=1.24 in /usr/local/lib/python3.10/dist-packages (from uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.25.0)
# Collecting opentelemetry-exporter-otlp~=1.24 (from uptrace<2.0.0,>=1.22.0->chainlit==1.1.304)
#   Downloading opentelemetry_exporter_otlp-1.25.0-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: opentelemetry-instrumentation~=0.45b0 in /usr/local/lib/python3.10/dist-packages (from uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (0.46b0)
# Requirement already satisfied: opentelemetry-sdk~=1.24 in /usr/local/lib/python3.10/dist-packages (from uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.25.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.4.0->asyncer<0.0.3,>=0.0.2->chainlit==1.1.304) (1.2.1)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.2.14)
# Requirement already satisfied: importlib-metadata<=7.1,>=6.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-api~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (7.1.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc==1.25.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.25.0)
# Collecting opentelemetry-exporter-otlp-proto-http==1.25.0 (from opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.25.0-py3-none-any.whl (16 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.63.2)
# Requirement already satisfied: grpcio<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.64.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.25.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.25.0)
# Requirement already satisfied: opentelemetry-proto==1.25.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.25.0)
# Requirement already satisfied: requests~=2.7 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-exporter-otlp-proto-http==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (2.31.0)
# Requirement already satisfied: protobuf<5.0,>=3.19 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-proto==1.25.0->opentelemetry-exporter-otlp-proto-grpc==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (3.20.3)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation~=0.45b0->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (67.7.2)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-instrumentation~=0.45b0->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (1.14.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.46b0 in /usr/local/lib/python3.10/dist-packages (from opentelemetry-sdk~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (0.46b0)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit==1.1.304)
#   Downloading simple_websocket-1.0.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses_json<0.6.0,>=0.5.7->chainlit==1.1.304) (1.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata<=7.1,>=6.0->opentelemetry-api~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (3.19.2)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.8.0->python-socketio<6.0.0,>=5.11.0->chainlit==1.1.304)
#   Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests~=2.7->opentelemetry-exporter-otlp-proto-http==1.25.0->opentelemetry-exporter-otlp~=1.24->uptrace<2.0.0,>=1.22.0->chainlit==1.1.304) (2.0.7)
# Building wheels for collected packages: literalai, syncer
#   Building wheel for literalai (setup.py) ... done
#   Created wheel for literalai: filename=literalai-0.0.604-py3-none-any.whl size=60741 sha256=a28c583d63f3699037214c29830db69e44408e44771112002b5b14d871a1e2c5
#   Stored in directory: /root/.cache/pip/wheels/bd/7a/94/a6ed7f613406b97e217393654a6aaabcc7023c1264f21ed4f1
#   Building wheel for syncer (setup.py) ... done
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3436 sha256=288df7d6b8f766e2bdde882abed491f8df092ff7cb9867b743f25f48ed6be1a5
#   Stored in directory: /root/.cache/pip/wheels/09/e4/36/bcaad665bcc2b672888ff2df1a5a1dc638378d8765055313cd
# Successfully built literalai syncer
# Installing collected packages: syncer, lazify, filetype, chevron, wsproto, uvicorn, pyjwt, packaging, numpy, aiofiles, watchfiles, simple-websocket, asyncer, python-engineio, literalai, fastapi, dataclasses_json, python-socketio, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp, uptrace, chainlit
#   Attempting uninstall: uvicorn
#     Found existing installation: uvicorn 0.30.1
#     Uninstalling uvicorn-0.30.1:
#       Successfully uninstalled uvicorn-0.30.1
#   Attempting uninstall: pyjwt
#     Found existing installation: PyJWT 2.3.0
#     Uninstalling PyJWT-2.3.0:
#       Successfully uninstalled PyJWT-2.3.0
#   Attempting uninstall: packaging
#     Found existing installation: packaging 24.1
#     Uninstalling packaging-24.1:
#       Successfully uninstalled packaging-24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: watchfiles
#     Found existing installation: watchfiles 0.22.0
#     Uninstalling watchfiles-0.22.0:
#       Successfully uninstalled watchfiles-0.22.0
#   Attempting uninstall: fastapi
#     Found existing installation: fastapi 0.111.0
#     Uninstalling fastapi-0.111.0:
#       Successfully uninstalled fastapi-0.111.0
#   Attempting uninstall: dataclasses_json
#     Found existing installation: dataclasses-json 0.6.7
#     Uninstalling dataclasses-json-0.6.7:
#       Successfully uninstalled dataclasses-json-0.6.7
# Successfully installed aiofiles-23.2.1 asyncer-0.0.2 chainlit-1.1.304 chevron-0.14.0 dataclasses_json-0.5.14 fastapi-0.110.3 filetype-1.2.0 lazify-0.4.0 literalai-0.0.604 numpy-1.26.4 opentelemetry-exporter-otlp-1.25.0 opentelemetry-exporter-otlp-proto-http-1.25.0 packaging-23.2 pyjwt-2.8.0 python-engineio-4.9.1 python-socketio-5.11.3 simple-websocket-1.0.0 syncer-2.0.3 uptrace-1.24.0 uvicorn-0.25.0 watchfiles-0.20.0 wsproto-1.2.0
# /tools/node/bin/lt -> /tools/node/lib/node_modules/localtunnel/bin/lt.js
# + localtunnel@2.0.2
# added 22 packages from 22 contributors in 2.501s
# /tools/node/bin/npm -> /tools/node/lib/node_modules/npm/bin/npm-cli.js
# /tools/node/bin/npx -> /tools/node/lib/node_modules/npm/bin/npx-cli.js
# npm WARN notsup Unsupported engine for npm@10.8.1: wanted: {"node":"^18.17.0 || >=20.5.0"} (current: {"node":"14.16.0","npm":"6.14.8"})
# npm WARN notsup Not compatible with your version of node/npm: npm@10.8.1
#
# + npm@10.8.1
# added 93 packages from 25 contributors, removed 321 packages and updated 113 packages in 6.418s

# %%
# %%writefile app.py

import chainlit as cl
import torch

from chainlit.types import AskFileResponse

from transformers import BitsAndBytesConfig
from transformers import AutoTokenizer , AutoModelForCausalLM , pipeline
from langchain_huggingface.llms import HuggingFacePipeline

from langchain.memory import ConversationBufferMemory
from langchain_community.chat_message_histories import ChatMessageHistory

from langchain.chains import ConversationalRetrievalChain

from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_community.document_loaders import PyPDFLoader , TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from langchain import hub


text_splitter = RecursiveCharacterTextSplitter(chunk_size =1000, chunk_overlap = 100)
embedding = HuggingFaceEmbeddings()


def process_file (file: AskFileResponse):
  if file.type == "text/plain":
    Loader = TextLoader
  elif file.type == "application/pdf":
    Loader = PyPDFLoader

  loader = Loader (file.path)
  documents = loader.load()
  docs = text_splitter.split_documents(documents)

  for i, doc in enumerate(docs):
    doc.metadata ["source"] = f"source_{i}"
    return docs


def get_vector_db(file: AskFileResponse):
    docs = process_file(file)
    cl.user_session.set("docs", docs)
    vector_db = Chroma.from_documents(documents=docs, embedding=embedding)
    return vector_db


def get_huggingface_llm(model_name: str = "lmsys/vicuna-7b-v1.5", max_new_token: int = 512):
    nf4_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True,
        bnb_4bit_compute_dtype=torch.bfloat16
    )

    model = AutoModelForCausalLM.from_pretrained(
        model_name,
        quantization_config=nf4_config,
        low_cpu_mem_usage=True
    )

    tokenizer = AutoTokenizer.from_pretrained(model_name)

    model_pipeline = pipeline(
        "text-generation",
        model=model,
        tokenizer=tokenizer,
        max_new_tokens=max_new_token,
        pad_token_id=tokenizer.eos_token_id,
        device_map="auto"
    )

    llm = HuggingFacePipeline(
        pipeline=model_pipeline,
    )

    return llm

LLM = get_huggingface_llm()


welcome_message = """Welcome to the PDF QA! To get started:
1. Upload a PDF or text file
2. Ask a question about the file
"""


@cl.on_chat_start
async def on_chat_start():
    files = None
    while files is None:
        files = await cl.AskFileMessage(
            content=welcome_message,
            accept=["text/plain", "application/pdf"],
            max_size_mb=20,
            timeout=180,
        ).send()

    file = files[0]

    msg = cl.Message(content=f"Processing '{file.name}'...", disable_feedback=True)
    await msg.send()

    vector_db = await cl.make_async(get_vector_db)(file)

    message_history = ChatMessageHistory()
    memory = ConversationBufferMemory(
        memory_key="chat_history",
        output_key="answer",
        chat_memory=message_history,
        return_messages=True,
    )

    retriever = vector_db.as_retriever(
        search_type="mmr",
        search_kwargs={'k': 3}
    )

    chain = ConversationalRetrievalChain.from_llm(
        llm=LLM,
        chain_type="stuff",
        retriever=retriever,
        memory=memory,
        return_source_documents=True
    )

    msg.content = f"'{file.name}' processed. You can now ask questions!"
    await msg.update()

    cl.user_session.set("chain", chain)


@cl.on_message
async def on_message(message: cl.Message):
    chain = cl.user_session.get("chain")
    cb = cl.AsyncLangchainCallbackHandler()
    res = await chain.ainvoke(message.content, callbacks=[cb])

    answer = res["answer"]
    source_documents = res["source_documents"]
    text_elements = []

    if source_documents:
        for source_idx, source_doc in enumerate(source_documents):
            source_name = f"source_{source_idx}"
            text_elements.append(
                cl.Text(content=source_doc.page_content, name=source_name)
            )

        source_names = [text_el.name for text_el in text_elements]

        if source_names:
            answer += f"\nSources: {', '.join(source_names)}"
        else:
            answer += "\nNo sources found"

    await cl.Message(content=answer, elements=text_elements).send()
# Out:
# Writing app.py

# %% [markdown]
# ## MAIN

# %%
# !pip install pyngrok -q

# %%
from pyngrok import ngrok
# Add your url-token
# !ngrok config add-authtoken <url_token>
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
public_url = ngrok.connect(8000).public_url
print(public_url)

# %%
# !chainlit run app.py
# Out:
# 2024-07-05 06:22:24 - Created default config file at /content/.chainlit/config.toml
# 2024-07-05 06:22:24 - Created default translation directory at /content/.chainlit/translations
# 2024-07-05 06:22:24 - Created default translation file at /content/.chainlit/translations/en-US.json
# WARNING:pyngrok.process.ngrok:t=2024-07-05T06:22:34+0000 lvl=warn msg="failed to open private leg" id=c2c371747b22 privaddr=localhost:8000 err="dial tcp 127.0.0.1:8000: connect: connection refused"
# 2024-07-05 06:22:34.618600: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-05 06:22:34.618654: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-05 06:22:34.763450: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-05 06:22:35.070532: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:pyngrok.process.ngrok:t=2024-07-05T06:22:35+0000 lvl=warn msg="failed to open private leg" id=33e9c9ead859 privaddr=localhost:8000 err="dial tcp 127.0.0.1:8000: connect: connection refused"
# 2024-07-05 06:22:38.471345: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-07-05 06:22:46 - Use pytorch device_name: cuda
# 2024-07-05 06:22:46 - Load pretrained SentenceTransformer: sentence-transformers/all-mpnet-base-v2
# modules.json: 100% 349/349 [00:00<00:00, 1.81MB/s]
# config_sentence_transformers.json: 100% 116/116 [00:00<00:00, 725kB/s]
# README.md: 100% 10.6k/10.6k [00:00<00:00, 45.9MB/s]
# sentence_bert_config.json: 100% 53.0/53.0 [00:00<00:00, 341kB/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json: 100% 571/571 [00:00<00:00, 3.58MB/s]
# model.safetensors: 100% 438M/438M [00:02<00:00, 149MB/s]
# tokenizer_config.json: 100% 363/363 [00:00<00:00, 2.21MB/s]
# vocab.txt: 100% 232k/232k [00:00<00:00, 50.8MB/s]
# tokenizer.json: 100% 466k/466k [00:00<00:00, 725kB/s]
# special_tokens_map.json: 100% 239/239 [00:00<00:00, 1.35MB/s]
# 1_Pooling/config.json: 100% 190/190 [00:00<00:00, 1.25MB/s]
# config.json: 100% 615/615 [00:00<00:00, 3.79MB/s]
# pytorch_model.bin.index.json: 100% 26.8k/26.8k [00:00<00:00, 96.3MB/s]
# Downloading shards:   0% 0/2 [00:00<?, ?it/s]
# pytorch_model-00001-of-00002.bin:   0% 0.00/9.98G [00:00<?, ?B/s]
# pytorch_model-00001-of-00002.bin:   0% 41.9M/9.98G [00:00<00:25, 390MB/s]
# pytorch_model-00001-of-00002.bin:   1% 94.4M/9.98G [00:00<00:21, 453MB/s]
# pytorch_model-00001-of-00002.bin:   1% 147M/9.98G [00:00<00:28, 348MB/s]
# pytorch_model-00001-of-00002.bin:   2% 189M/9.98G [00:00<00:29, 333MB/s]
# pytorch_model-00001-of-00002.bin:   2% 231M/9.98G [00:00<00:29, 331MB/s]
# pytorch_model-00001-of-00002.bin:   3% 273M/9.98G [00:00<00:29, 333MB/s]
# pytorch_model-00001-of-00002.bin:   3% 315M/9.98G [00:00<00:29, 330MB/s]
# pytorch_model-00001-of-00002.bin:   4% 367M/9.98G [00:01<00:27, 349MB/s]
# pytorch_model-00001-of-00002.bin:   4% 409M/9.98G [00:01<00:27, 345MB/s]
# pytorch_model-00001-of-00002.bin:   5% 451M/9.98G [00:01<00:27, 341MB/s]
# pytorch_model-00001-of-00002.bin:   5% 493M/9.98G [00:01<00:31, 299MB/s]
# pytorch_model-00001-of-00002.bin:   5% 535M/9.98G [00:01<00:30, 310MB/s]
# pytorch_model-00001-of-00002.bin:   6% 577M/9.98G [00:01<00:33, 278MB/s]
# pytorch_model-00001-of-00002.bin:   6% 608M/9.98G [00:01<00:33, 284MB/s]
# pytorch_model-00001-of-00002.bin:   6% 640M/9.98G [00:02<00:34, 274MB/s]
# pytorch_model-00001-of-00002.bin:   7% 682M/9.98G [00:02<00:31, 294MB/s]
# pytorch_model-00001-of-00002.bin:   7% 713M/9.98G [00:02<00:35, 263MB/s]
# pytorch_model-00001-of-00002.bin:   7% 744M/9.98G [00:02<00:35, 259MB/s]
# pytorch_model-00001-of-00002.bin:   8% 776M/9.98G [00:02<00:34, 269MB/s]
# pytorch_model-00001-of-00002.bin:   8% 807M/9.98G [00:02<00:41, 220MB/s]
# pytorch_model-00001-of-00002.bin:   8% 839M/9.98G [00:02<00:41, 219MB/s]
# pytorch_model-00001-of-00002.bin:   9% 870M/9.98G [00:03<00:41, 222MB/s]
# pytorch_model-00001-of-00002.bin:   9% 902M/9.98G [00:03<00:42, 212MB/s]
# pytorch_model-00001-of-00002.bin:   9% 933M/9.98G [00:03<00:42, 210MB/s]
# pytorch_model-00001-of-00002.bin:  10% 965M/9.98G [00:03<00:42, 213MB/s]
# pytorch_model-00001-of-00002.bin:  10% 996M/9.98G [00:03<00:39, 227MB/s]
# pytorch_model-00001-of-00002.bin:  10% 1.03G/9.98G [00:03<00:38, 235MB/s]
# pytorch_model-00001-of-00002.bin:  11% 1.06G/9.98G [00:03<00:36, 241MB/s]
# pytorch_model-00001-of-00002.bin:  11% 1.09G/9.98G [00:04<00:38, 230MB/s]
# pytorch_model-00001-of-00002.bin:  11% 1.12G/9.98G [00:04<00:36, 243MB/s]
# pytorch_model-00001-of-00002.bin:  12% 1.15G/9.98G [00:04<00:36, 239MB/s]
# pytorch_model-00001-of-00002.bin:  12% 1.18G/9.98G [00:04<00:39, 221MB/s]
# pytorch_model-00001-of-00002.bin:  12% 1.22G/9.98G [00:04<00:38, 229MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.25G/9.98G [00:04<00:38, 228MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.29G/9.98G [00:04<00:33, 256MB/s]
# pytorch_model-00001-of-00002.bin:  13% 1.32G/9.98G [00:04<00:36, 236MB/s]
# pytorch_model-00001-of-00002.bin:  14% 1.35G/9.98G [00:05<00:37, 227MB/s]
# pytorch_model-00001-of-00002.bin:  14% 1.38G/9.98G [00:05<00:36, 235MB/s]
# pytorch_model-00001-of-00002.bin:  14% 1.42G/9.98G [00:05<00:36, 236MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.45G/9.98G [00:05<00:35, 239MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.48G/9.98G [00:05<00:35, 240MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.51G/9.98G [00:05<00:34, 243MB/s]
# pytorch_model-00001-of-00002.bin:  15% 1.54G/9.98G [00:05<00:34, 246MB/s]
# pytorch_model-00001-of-00002.bin:  16% 1.57G/9.98G [00:06<00:34, 243MB/s]
# pytorch_model-00001-of-00002.bin:  16% 1.60G/9.98G [00:06<00:34, 245MB/s]
# pytorch_model-00001-of-00002.bin:  16% 1.64G/9.98G [00:06<00:33, 252MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.67G/9.98G [00:06<00:32, 259MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.70G/9.98G [00:06<00:32, 252MB/s]
# pytorch_model-00001-of-00002.bin:  17% 1.73G/9.98G [00:06<00:33, 248MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.76G/9.98G [00:06<00:34, 240MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.79G/9.98G [00:06<00:33, 243MB/s]
# pytorch_model-00001-of-00002.bin:  18% 1.82G/9.98G [00:07<00:34, 239MB/s]
# pytorch_model-00001-of-00002.bin:  19% 1.86G/9.98G [00:07<00:36, 225MB/s]
# pytorch_model-00001-of-00002.bin:  19% 1.89G/9.98G [00:07<00:34, 232MB/s]
# pytorch_model-00001-of-00002.bin:  19% 1.92G/9.98G [00:07<00:34, 234MB/s]
# pytorch_model-00001-of-00002.bin:  20% 1.95G/9.98G [00:07<00:33, 237MB/s]
# pytorch_model-00001-of-00002.bin:  20% 1.99G/9.98G [00:07<00:32, 248MB/s]
# pytorch_model-00001-of-00002.bin:  20% 2.02G/9.98G [00:07<00:33, 235MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.07G/9.98G [00:08<00:29, 264MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.10G/9.98G [00:08<00:28, 275MB/s]
# pytorch_model-00001-of-00002.bin:  21% 2.14G/9.98G [00:08<00:27, 280MB/s]
# pytorch_model-00001-of-00002.bin:  22% 2.18G/9.98G [00:08<00:25, 304MB/s]
# pytorch_model-00001-of-00002.bin:  22% 2.21G/9.98G [00:08<00:27, 285MB/s]
# pytorch_model-00001-of-00002.bin:  22% 2.24G/9.98G [00:08<00:27, 278MB/s]
# pytorch_model-00001-of-00002.bin:  23% 2.28G/9.98G [00:08<00:28, 266MB/s]
# pytorch_model-00001-of-00002.bin:  23% 2.31G/9.98G [00:08<00:31, 240MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.35G/9.98G [00:09<00:27, 274MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.38G/9.98G [00:09<00:27, 279MB/s]
# pytorch_model-00001-of-00002.bin:  24% 2.42G/9.98G [00:09<00:25, 302MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.45G/9.98G [00:09<00:24, 304MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.50G/9.98G [00:09<00:23, 315MB/s]
# pytorch_model-00001-of-00002.bin:  25% 2.54G/9.98G [00:09<00:23, 319MB/s]
# pytorch_model-00001-of-00002.bin:  26% 2.58G/9.98G [00:09<00:22, 324MB/s]
# pytorch_model-00001-of-00002.bin:  26% 2.62G/9.98G [00:09<00:24, 303MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.65G/9.98G [00:10<00:26, 279MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.68G/9.98G [00:10<00:26, 273MB/s]
# pytorch_model-00001-of-00002.bin:  27% 2.72G/9.98G [00:10<00:26, 278MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.75G/9.98G [00:10<00:26, 268MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.78G/9.98G [00:10<00:29, 243MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.81G/9.98G [00:10<00:29, 244MB/s]
# pytorch_model-00001-of-00002.bin:  28% 2.84G/9.98G [00:10<00:27, 258MB/s]
# pytorch_model-00001-of-00002.bin:  29% 2.87G/9.98G [00:10<00:27, 259MB/s]
# pytorch_model-00001-of-00002.bin:  29% 2.90G/9.98G [00:11<00:31, 225MB/s]
# pytorch_model-00001-of-00002.bin:  29% 2.94G/9.98G [00:11<00:28, 244MB/s]
# pytorch_model-00001-of-00002.bin:  30% 2.98G/9.98G [00:11<00:25, 273MB/s]
# pytorch_model-00001-of-00002.bin:  30% 3.01G/9.98G [00:11<00:27, 253MB/s]
# pytorch_model-00001-of-00002.bin:  30% 3.04G/9.98G [00:13<02:33, 45.2MB/s]
# pytorch_model-00001-of-00002.bin:  31% 3.09G/9.98G [00:13<01:36, 71.3MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.15G/9.98G [00:13<01:06, 103MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.19G/9.98G [00:15<01:46, 63.8MB/s]
# pytorch_model-00001-of-00002.bin:  32% 3.23G/9.98G [00:15<01:19, 84.5MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.27G/9.98G [00:15<01:00, 110MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.30G/9.98G [00:16<01:53, 58.9MB/s]
# pytorch_model-00001-of-00002.bin:  33% 3.33G/9.98G [00:16<01:29, 74.0MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.38G/9.98G [00:16<01:06, 99.3MB/s]
# pytorch_model-00001-of-00002.bin:  34% 3.42G/9.98G [00:16<00:51, 128MB/s]
# pytorch_model-00001-of-00002.bin:  35% 3.46G/9.98G [00:17<00:40, 161MB/s]
# pytorch_model-00001-of-00002.bin:  35% 3.50G/9.98G [00:17<00:33, 193MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.54G/9.98G [00:17<00:28, 227MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.59G/9.98G [00:17<00:25, 251MB/s]
# pytorch_model-00001-of-00002.bin:  36% 3.63G/9.98G [00:17<00:24, 260MB/s]
# pytorch_model-00001-of-00002.bin:  37% 3.67G/9.98G [00:17<00:24, 259MB/s]
# pytorch_model-00001-of-00002.bin:  37% 3.70G/9.98G [00:17<00:24, 256MB/s]
# pytorch_model-00001-of-00002.bin:  37% 3.73G/9.98G [00:18<00:28, 219MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.76G/9.98G [00:18<00:26, 236MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.80G/9.98G [00:18<00:25, 238MB/s]
# pytorch_model-00001-of-00002.bin:  38% 3.83G/9.98G [00:18<00:25, 243MB/s]
# pytorch_model-00001-of-00002.bin:  39% 3.86G/9.98G [00:18<00:25, 244MB/s]
# pytorch_model-00001-of-00002.bin:  39% 3.89G/9.98G [00:18<00:24, 247MB/s]
# pytorch_model-00001-of-00002.bin:  39% 3.92G/9.98G [00:18<00:24, 252MB/s]
# pytorch_model-00001-of-00002.bin:  40% 3.95G/9.98G [00:18<00:24, 248MB/s]
# pytorch_model-00001-of-00002.bin:  40% 3.98G/9.98G [00:19<00:24, 245MB/s]
# pytorch_model-00001-of-00002.bin:  40% 4.02G/9.98G [00:19<00:24, 242MB/s]
# pytorch_model-00001-of-00002.bin:  41% 4.05G/9.98G [00:19<00:25, 237MB/s]
# pytorch_model-00001-of-00002.bin:  41% 4.08G/9.98G [00:19<00:24, 238MB/s]
# pytorch_model-00001-of-00002.bin:  41% 4.11G/9.98G [00:19<00:25, 228MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.14G/9.98G [00:19<00:28, 205MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.17G/9.98G [00:19<00:26, 220MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.20G/9.98G [00:20<00:24, 233MB/s]
# pytorch_model-00001-of-00002.bin:  42% 4.24G/9.98G [00:20<00:23, 241MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.27G/9.98G [00:20<00:23, 248MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.30G/9.98G [00:20<00:22, 254MB/s]
# pytorch_model-00001-of-00002.bin:  43% 4.33G/9.98G [00:20<00:23, 242MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.36G/9.98G [00:20<00:22, 248MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.39G/9.98G [00:20<00:22, 245MB/s]
# pytorch_model-00001-of-00002.bin:  44% 4.42G/9.98G [00:20<00:23, 238MB/s]
# pytorch_model-00001-of-00002.bin:  45% 4.46G/9.98G [00:21<00:23, 232MB/s]
# pytorch_model-00001-of-00002.bin:  45% 4.49G/9.98G [00:21<00:22, 243MB/s]
# pytorch_model-00001-of-00002.bin:  45% 4.52G/9.98G [00:21<00:21, 251MB/s]
# pytorch_model-00001-of-00002.bin:  46% 4.55G/9.98G [00:21<00:21, 248MB/s]
# pytorch_model-00001-of-00002.bin:  46% 4.58G/9.98G [00:21<00:21, 250MB/s]
# pytorch_model-00001-of-00002.bin:  46% 4.61G/9.98G [00:21<00:22, 237MB/s]
# pytorch_model-00001-of-00002.bin:  47% 4.65G/9.98G [00:21<00:21, 252MB/s]
# pytorch_model-00001-of-00002.bin:  47% 4.68G/9.98G [00:21<00:20, 256MB/s]
# pytorch_model-00001-of-00002.bin:  47% 4.71G/9.98G [00:22<00:20, 257MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.74G/9.98G [00:22<00:20, 259MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.77G/9.98G [00:22<00:20, 251MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.80G/9.98G [00:22<00:20, 254MB/s]
# pytorch_model-00001-of-00002.bin:  48% 4.83G/9.98G [00:22<00:20, 250MB/s]
# pytorch_model-00001-of-00002.bin:  49% 4.87G/9.98G [00:22<00:20, 245MB/s]
# pytorch_model-00001-of-00002.bin:  49% 4.90G/9.98G [00:22<00:21, 239MB/s]
# pytorch_model-00001-of-00002.bin:  49% 4.93G/9.98G [00:22<00:21, 233MB/s]
# pytorch_model-00001-of-00002.bin:  50% 4.96G/9.98G [00:23<00:21, 230MB/s]
# pytorch_model-00001-of-00002.bin:  50% 5.00G/9.98G [00:23<00:18, 270MB/s]
# pytorch_model-00001-of-00002.bin:  50% 5.03G/9.98G [00:23<00:18, 268MB/s]
# pytorch_model-00001-of-00002.bin:  51% 5.06G/9.98G [00:23<00:18, 259MB/s]
# pytorch_model-00001-of-00002.bin:  51% 5.10G/9.98G [00:23<00:19, 245MB/s]
# pytorch_model-00001-of-00002.bin:  51% 5.13G/9.98G [00:23<00:20, 239MB/s]
# pytorch_model-00001-of-00002.bin:  52% 5.16G/9.98G [00:23<00:21, 220MB/s]
# pytorch_model-00001-of-00002.bin:  52% 5.19G/9.98G [00:24<00:21, 224MB/s]
# pytorch_model-00001-of-00002.bin:  52% 5.23G/9.98G [00:24<00:18, 253MB/s]
# pytorch_model-00001-of-00002.bin:  53% 5.27G/9.98G [00:24<00:17, 275MB/s]
# pytorch_model-00001-of-00002.bin:  53% 5.31G/9.98G [00:24<00:16, 276MB/s]
# pytorch_model-00001-of-00002.bin:  53% 5.34G/9.98G [00:24<00:16, 282MB/s]
# pytorch_model-00001-of-00002.bin:  54% 5.38G/9.98G [00:24<00:15, 298MB/s]
# pytorch_model-00001-of-00002.bin:  54% 5.41G/9.98G [00:24<00:15, 289MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.44G/9.98G [00:24<00:16, 277MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.47G/9.98G [00:25<00:16, 276MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.51G/9.98G [00:25<00:17, 263MB/s]
# pytorch_model-00001-of-00002.bin:  55% 5.54G/9.98G [00:25<00:16, 262MB/s]
# pytorch_model-00001-of-00002.bin:  56% 5.57G/9.98G [00:25<00:17, 250MB/s]
# pytorch_model-00001-of-00002.bin:  56% 5.60G/9.98G [00:25<00:17, 248MB/s]
# pytorch_model-00001-of-00002.bin:  56% 5.63G/9.98G [00:25<00:17, 254MB/s]
# pytorch_model-00001-of-00002.bin:  57% 5.66G/9.98G [00:25<00:17, 246MB/s]
# pytorch_model-00001-of-00002.bin:  57% 5.69G/9.98G [00:27<01:38, 43.5MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.75G/9.98G [00:28<01:00, 70.2MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.78G/9.98G [00:28<00:48, 86.6MB/s]
# pytorch_model-00001-of-00002.bin:  58% 5.81G/9.98G [00:28<00:39, 106MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.84G/9.98G [00:28<00:32, 126MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.88G/9.98G [00:28<00:25, 160MB/s]
# pytorch_model-00001-of-00002.bin:  59% 5.92G/9.98G [00:28<00:21, 191MB/s]
# pytorch_model-00001-of-00002.bin:  60% 5.97G/9.98G [00:28<00:17, 225MB/s]
# pytorch_model-00001-of-00002.bin:  60% 6.01G/9.98G [00:28<00:15, 249MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.05G/9.98G [00:29<00:14, 267MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.09G/9.98G [00:29<00:12, 299MB/s]
# pytorch_model-00001-of-00002.bin:  61% 6.13G/9.98G [00:29<00:14, 265MB/s]
# pytorch_model-00001-of-00002.bin:  62% 6.18G/9.98G [00:29<00:13, 276MB/s]
# pytorch_model-00001-of-00002.bin:  62% 6.21G/9.98G [00:29<00:14, 254MB/s]
# pytorch_model-00001-of-00002.bin:  63% 6.25G/9.98G [00:29<00:13, 279MB/s]
# pytorch_model-00001-of-00002.bin:  63% 6.28G/9.98G [00:29<00:16, 223MB/s]
# pytorch_model-00001-of-00002.bin:  63% 6.32G/9.98G [00:30<00:14, 249MB/s]
# pytorch_model-00001-of-00002.bin:  64% 6.36G/9.98G [00:30<00:13, 270MB/s]
# pytorch_model-00001-of-00002.bin:  64% 6.40G/9.98G [00:30<00:12, 276MB/s]
# pytorch_model-00001-of-00002.bin:  64% 6.43G/9.98G [00:30<00:13, 269MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.46G/9.98G [00:30<00:13, 258MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.49G/9.98G [00:30<00:13, 259MB/s]
# pytorch_model-00001-of-00002.bin:  65% 6.52G/9.98G [00:30<00:14, 238MB/s]
# pytorch_model-00001-of-00002.bin:  66% 6.55G/9.98G [00:31<00:14, 242MB/s]
# pytorch_model-00001-of-00002.bin:  66% 6.60G/9.98G [00:31<00:13, 248MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.64G/9.98G [00:31<00:12, 261MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.67G/9.98G [00:31<00:12, 265MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.70G/9.98G [00:31<00:13, 240MB/s]
# pytorch_model-00001-of-00002.bin:  67% 6.73G/9.98G [00:31<00:13, 244MB/s]
# pytorch_model-00001-of-00002.bin:  68% 6.76G/9.98G [00:31<00:13, 236MB/s]
# pytorch_model-00001-of-00002.bin:  68% 6.79G/9.98G [00:32<00:14, 216MB/s]
# pytorch_model-00001-of-00002.bin:  68% 6.83G/9.98G [00:32<00:14, 223MB/s]
# pytorch_model-00001-of-00002.bin:  69% 6.86G/9.98G [00:32<00:13, 224MB/s]
# pytorch_model-00001-of-00002.bin:  69% 6.90G/9.98G [00:32<00:11, 262MB/s]
# pytorch_model-00001-of-00002.bin:  70% 6.94G/9.98G [00:32<00:10, 285MB/s]
# pytorch_model-00001-of-00002.bin:  70% 6.97G/9.98G [00:32<00:10, 273MB/s]
# pytorch_model-00001-of-00002.bin:  70% 7.00G/9.98G [00:32<00:10, 270MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.05G/9.98G [00:32<00:10, 280MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.08G/9.98G [00:33<00:11, 251MB/s]
# pytorch_model-00001-of-00002.bin:  71% 7.11G/9.98G [00:33<00:12, 237MB/s]
# pytorch_model-00001-of-00002.bin:  72% 7.14G/9.98G [00:33<00:12, 234MB/s]
# pytorch_model-00001-of-00002.bin:  72% 7.17G/9.98G [00:33<00:11, 239MB/s]
# pytorch_model-00001-of-00002.bin:  72% 7.20G/9.98G [00:33<00:10, 254MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.24G/9.98G [00:33<00:11, 241MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.27G/9.98G [00:33<00:11, 235MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.30G/9.98G [00:34<00:11, 235MB/s]
# pytorch_model-00001-of-00002.bin:  73% 7.33G/9.98G [00:34<00:11, 237MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.36G/9.98G [00:34<00:10, 246MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.39G/9.98G [00:34<00:10, 237MB/s]
# pytorch_model-00001-of-00002.bin:  74% 7.42G/9.98G [00:34<00:10, 233MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.46G/9.98G [00:34<00:10, 243MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.49G/9.98G [00:34<00:10, 248MB/s]
# pytorch_model-00001-of-00002.bin:  75% 7.52G/9.98G [00:34<00:09, 246MB/s]
# pytorch_model-00001-of-00002.bin:  76% 7.55G/9.98G [00:35<00:09, 251MB/s]
# pytorch_model-00001-of-00002.bin:  76% 7.58G/9.98G [00:35<00:09, 261MB/s]
# pytorch_model-00001-of-00002.bin:  76% 7.61G/9.98G [00:35<00:09, 252MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.64G/9.98G [00:35<00:16, 145MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.67G/9.98G [00:36<00:20, 113MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.69G/9.98G [00:36<00:22, 101MB/s]
# pytorch_model-00001-of-00002.bin:  77% 7.71G/9.98G [00:36<00:22, 101MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.74G/9.98G [00:36<00:17, 129MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.77G/9.98G [00:36<00:13, 159MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.79G/9.98G [00:36<00:13, 166MB/s]
# pytorch_model-00001-of-00002.bin:  78% 7.81G/9.98G [00:37<00:18, 115MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.83G/9.98G [00:37<00:20, 107MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.85G/9.98G [00:37<00:22, 92.8MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.87G/9.98G [00:38<00:23, 88.4MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.90G/9.98G [00:38<00:25, 82.3MB/s]
# pytorch_model-00001-of-00002.bin:  79% 7.93G/9.98G [00:38<00:18, 111MB/s]
# pytorch_model-00001-of-00002.bin:  80% 7.97G/9.98G [00:38<00:12, 155MB/s]
# pytorch_model-00001-of-00002.bin:  80% 8.01G/9.98G [00:39<00:29, 65.7MB/s]
# pytorch_model-00001-of-00002.bin:  81% 8.05G/9.98G [00:39<00:20, 91.7MB/s]
# pytorch_model-00001-of-00002.bin:  81% 8.08G/9.98G [00:40<00:18, 101MB/s]
# pytorch_model-00001-of-00002.bin:  81% 8.11G/9.98G [00:40<00:16, 112MB/s]
# pytorch_model-00001-of-00002.bin:  82% 8.15G/9.98G [00:40<00:12, 147MB/s]
# pytorch_model-00001-of-00002.bin:  82% 8.18G/9.98G [00:40<00:10, 171MB/s]
# pytorch_model-00001-of-00002.bin:  82% 8.22G/9.98G [00:40<00:08, 210MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.25G/9.98G [00:40<00:08, 215MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.28G/9.98G [00:40<00:07, 228MB/s]
# pytorch_model-00001-of-00002.bin:  83% 8.32G/9.98G [00:40<00:06, 243MB/s]
# pytorch_model-00001-of-00002.bin:  84% 8.35G/9.98G [00:41<00:06, 252MB/s]
# pytorch_model-00001-of-00002.bin:  84% 8.38G/9.98G [00:41<00:06, 230MB/s]
# pytorch_model-00001-of-00002.bin:  84% 8.42G/9.98G [00:41<00:06, 258MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.45G/9.98G [00:41<00:05, 259MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.48G/9.98G [00:41<00:05, 249MB/s]
# pytorch_model-00001-of-00002.bin:  85% 8.52G/9.98G [00:41<00:05, 262MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.56G/9.98G [00:41<00:05, 246MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.59G/9.98G [00:42<00:05, 261MB/s]
# pytorch_model-00001-of-00002.bin:  86% 8.62G/9.98G [00:42<00:05, 255MB/s]
# pytorch_model-00001-of-00002.bin:  87% 8.65G/9.98G [00:44<00:29, 44.7MB/s]
# pytorch_model-00001-of-00002.bin:  87% 8.70G/9.98G [00:44<00:17, 71.1MB/s]
# pytorch_model-00001-of-00002.bin:  88% 8.75G/9.98G [00:44<00:12, 94.9MB/s]
# pytorch_model-00001-of-00002.bin:  88% 8.78G/9.98G [00:44<00:11, 106MB/s]
# pytorch_model-00001-of-00002.bin:  88% 8.81G/9.98G [00:44<00:09, 129MB/s]
# pytorch_model-00001-of-00002.bin:  89% 8.84G/9.98G [00:44<00:07, 152MB/s]
# pytorch_model-00001-of-00002.bin:  89% 8.87G/9.98G [00:45<00:06, 174MB/s]
# pytorch_model-00001-of-00002.bin:  89% 8.90G/9.98G [00:45<00:05, 199MB/s]
# pytorch_model-00001-of-00002.bin:  90% 8.94G/9.98G [00:45<00:04, 241MB/s]
# pytorch_model-00001-of-00002.bin:  90% 8.99G/9.98G [00:45<00:03, 253MB/s]
# pytorch_model-00001-of-00002.bin:  90% 9.03G/9.98G [00:45<00:03, 276MB/s]
# pytorch_model-00001-of-00002.bin:  91% 9.07G/9.98G [00:45<00:03, 267MB/s]
# pytorch_model-00001-of-00002.bin:  91% 9.11G/9.98G [00:45<00:03, 279MB/s]
# pytorch_model-00001-of-00002.bin:  92% 9.14G/9.98G [00:45<00:02, 283MB/s]
# pytorch_model-00001-of-00002.bin:  92% 9.18G/9.98G [00:46<00:03, 210MB/s]
# pytorch_model-00001-of-00002.bin:  92% 9.22G/9.98G [00:46<00:03, 239MB/s]
# pytorch_model-00001-of-00002.bin:  93% 9.26G/9.98G [00:46<00:02, 272MB/s]
# pytorch_model-00001-of-00002.bin:  93% 9.30G/9.98G [00:46<00:02, 296MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.34G/9.98G [00:46<00:02, 270MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.37G/9.98G [00:46<00:02, 218MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.41G/9.98G [00:47<00:03, 174MB/s]
# pytorch_model-00001-of-00002.bin:  94% 9.43G/9.98G [00:47<00:03, 154MB/s]
# pytorch_model-00001-of-00002.bin:  95% 9.45G/9.98G [00:47<00:03, 152MB/s]
# pytorch_model-00001-of-00002.bin:  95% 9.48G/9.98G [00:47<00:02, 170MB/s]
# pytorch_model-00001-of-00002.bin:  95% 9.51G/9.98G [00:47<00:02, 197MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.55G/9.98G [00:47<00:01, 235MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.58G/9.98G [00:48<00:01, 243MB/s]
# pytorch_model-00001-of-00002.bin:  96% 9.63G/9.98G [00:48<00:01, 267MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.66G/9.98G [00:48<00:01, 250MB/s]
# pytorch_model-00001-of-00002.bin:  97% 9.70G/9.98G [00:48<00:01, 276MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.73G/9.98G [00:48<00:00, 270MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.76G/9.98G [00:48<00:00, 253MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.79G/9.98G [00:48<00:00, 236MB/s]
# pytorch_model-00001-of-00002.bin:  98% 9.83G/9.98G [00:49<00:00, 239MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.86G/9.98G [00:50<00:02, 58.4MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.88G/9.98G [00:50<00:01, 66.4MB/s]
# pytorch_model-00001-of-00002.bin:  99% 9.92G/9.98G [00:50<00:00, 94.8MB/s]
# pytorch_model-00001-of-00002.bin: 100% 9.95G/9.98G [00:50<00:00, 115MB/s]
# pytorch_model-00001-of-00002.bin: 100% 9.98G/9.98G [00:51<00:00, 195MB/s]
# Downloading shards:  50% 1/2 [00:51<00:51, 51.41s/it]
# pytorch_model-00002-of-00002.bin:   0% 0.00/3.50G [00:00<?, ?B/s]
# pytorch_model-00002-of-00002.bin:   1% 31.5M/3.50G [00:00<00:11, 297MB/s]
# pytorch_model-00002-of-00002.bin:   2% 73.4M/3.50G [00:00<00:10, 330MB/s]
# pytorch_model-00002-of-00002.bin:   3% 115M/3.50G [00:00<00:09, 354MB/s]
# pytorch_model-00002-of-00002.bin:   4% 157M/3.50G [00:00<00:09, 351MB/s]
# pytorch_model-00002-of-00002.bin:   6% 199M/3.50G [00:00<00:08, 368MB/s]
# pytorch_model-00002-of-00002.bin:   7% 241M/3.50G [00:00<00:09, 340MB/s]
# pytorch_model-00002-of-00002.bin:   8% 283M/3.50G [00:00<00:10, 317MB/s]
# pytorch_model-00002-of-00002.bin:   9% 325M/3.50G [00:01<00:11, 285MB/s]
# pytorch_model-00002-of-00002.bin:  10% 357M/3.50G [00:01<00:12, 257MB/s]
# pytorch_model-00002-of-00002.bin:  11% 398M/3.50G [00:01<00:11, 277MB/s]
# pytorch_model-00002-of-00002.bin:  12% 430M/3.50G [00:01<00:11, 263MB/s]
# pytorch_model-00002-of-00002.bin:  13% 461M/3.50G [00:01<00:11, 265MB/s]
# pytorch_model-00002-of-00002.bin:  14% 493M/3.50G [00:01<00:11, 273MB/s]
# pytorch_model-00002-of-00002.bin:  15% 524M/3.50G [00:01<00:11, 270MB/s]
# pytorch_model-00002-of-00002.bin:  16% 556M/3.50G [00:01<00:11, 252MB/s]
# pytorch_model-00002-of-00002.bin:  17% 587M/3.50G [00:02<00:14, 203MB/s]
# pytorch_model-00002-of-00002.bin:  18% 619M/3.50G [00:02<00:18, 158MB/s]
# pytorch_model-00002-of-00002.bin:  18% 640M/3.50G [00:02<00:20, 139MB/s]
# pytorch_model-00002-of-00002.bin:  19% 661M/3.50G [00:02<00:19, 144MB/s]
# pytorch_model-00002-of-00002.bin:  20% 703M/3.50G [00:02<00:14, 189MB/s]
# pytorch_model-00002-of-00002.bin:  21% 744M/3.50G [00:04<00:49, 55.8MB/s]
# pytorch_model-00002-of-00002.bin:  22% 765M/3.50G [00:05<00:55, 49.5MB/s]
# pytorch_model-00002-of-00002.bin:  23% 818M/3.50G [00:05<00:33, 80.5MB/s]
# pytorch_model-00002-of-00002.bin:  25% 870M/3.50G [00:05<00:22, 116MB/s]
# pytorch_model-00002-of-00002.bin:  26% 912M/3.50G [00:05<00:17, 144MB/s]
# pytorch_model-00002-of-00002.bin:  27% 954M/3.50G [00:05<00:15, 167MB/s]
# pytorch_model-00002-of-00002.bin:  28% 986M/3.50G [00:05<00:14, 173MB/s]
# pytorch_model-00002-of-00002.bin:  29% 1.02G/3.50G [00:09<01:21, 30.5MB/s]
# pytorch_model-00002-of-00002.bin:  30% 1.06G/3.50G [00:09<00:56, 43.3MB/s]
# pytorch_model-00002-of-00002.bin:  31% 1.09G/3.50G [00:09<00:44, 53.8MB/s]
# pytorch_model-00002-of-00002.bin:  32% 1.13G/3.50G [00:09<00:32, 73.7MB/s]
# pytorch_model-00002-of-00002.bin:  33% 1.16G/3.50G [00:09<00:26, 87.7MB/s]
# pytorch_model-00002-of-00002.bin:  34% 1.20G/3.50G [00:10<00:21, 105MB/s]
# pytorch_model-00002-of-00002.bin:  35% 1.23G/3.50G [00:10<00:20, 110MB/s]
# pytorch_model-00002-of-00002.bin:  36% 1.27G/3.50G [00:10<00:15, 143MB/s]
# pytorch_model-00002-of-00002.bin:  37% 1.30G/3.50G [00:10<00:13, 164MB/s]
# pytorch_model-00002-of-00002.bin:  38% 1.33G/3.50G [00:10<00:12, 168MB/s]
# pytorch_model-00002-of-00002.bin:  39% 1.36G/3.50G [00:10<00:11, 182MB/s]
# pytorch_model-00002-of-00002.bin:  40% 1.39G/3.50G [00:11<00:11, 177MB/s]
# pytorch_model-00002-of-00002.bin:  40% 1.42G/3.50G [00:11<00:16, 127MB/s]
# pytorch_model-00002-of-00002.bin:  41% 1.44G/3.50G [00:15<01:49, 18.8MB/s]
# pytorch_model-00002-of-00002.bin:  43% 1.49G/3.50G [00:15<00:59, 33.6MB/s]
# pytorch_model-00002-of-00002.bin:  44% 1.53G/3.50G [00:15<00:40, 49.0MB/s]
# pytorch_model-00002-of-00002.bin:  45% 1.56G/3.50G [00:15<00:30, 63.0MB/s]
# pytorch_model-00002-of-00002.bin:  46% 1.59G/3.50G [00:16<00:24, 78.6MB/s]
# pytorch_model-00002-of-00002.bin:  47% 1.64G/3.50G [00:16<00:17, 108MB/s]
# pytorch_model-00002-of-00002.bin:  48% 1.67G/3.50G [00:16<00:14, 128MB/s]
# pytorch_model-00002-of-00002.bin:  49% 1.70G/3.50G [00:16<00:12, 148MB/s]
# pytorch_model-00002-of-00002.bin:  50% 1.74G/3.50G [00:16<00:09, 179MB/s]
# pytorch_model-00002-of-00002.bin:  51% 1.77G/3.50G [00:16<00:08, 194MB/s]
# pytorch_model-00002-of-00002.bin:  52% 1.81G/3.50G [00:16<00:07, 218MB/s]
# pytorch_model-00002-of-00002.bin:  53% 1.85G/3.50G [00:17<00:07, 228MB/s]
# pytorch_model-00002-of-00002.bin:  54% 1.88G/3.50G [00:17<00:07, 220MB/s]
# pytorch_model-00002-of-00002.bin:  55% 1.92G/3.50G [00:17<00:06, 245MB/s]
# pytorch_model-00002-of-00002.bin:  56% 1.95G/3.50G [00:17<00:06, 239MB/s]
# pytorch_model-00002-of-00002.bin:  57% 1.98G/3.50G [00:17<00:06, 231MB/s]
# pytorch_model-00002-of-00002.bin:  58% 2.02G/3.50G [00:17<00:05, 263MB/s]
# pytorch_model-00002-of-00002.bin:  59% 2.06G/3.50G [00:17<00:05, 252MB/s]
# pytorch_model-00002-of-00002.bin:  60% 2.09G/3.50G [00:17<00:05, 249MB/s]
# pytorch_model-00002-of-00002.bin:  61% 2.12G/3.50G [00:18<00:05, 245MB/s]
# pytorch_model-00002-of-00002.bin:  61% 2.15G/3.50G [00:18<00:05, 256MB/s]
# pytorch_model-00002-of-00002.bin:  62% 2.18G/3.50G [00:18<00:05, 248MB/s]
# pytorch_model-00002-of-00002.bin:  63% 2.21G/3.50G [00:18<00:05, 255MB/s]
# pytorch_model-00002-of-00002.bin:  64% 2.24G/3.50G [00:18<00:05, 243MB/s]
# pytorch_model-00002-of-00002.bin:  65% 2.28G/3.50G [00:18<00:04, 259MB/s]
# pytorch_model-00002-of-00002.bin:  66% 2.31G/3.50G [00:18<00:04, 253MB/s]
# pytorch_model-00002-of-00002.bin:  67% 2.34G/3.50G [00:18<00:04, 246MB/s]
# pytorch_model-00002-of-00002.bin:  68% 2.37G/3.50G [00:19<00:04, 252MB/s]
# pytorch_model-00002-of-00002.bin:  69% 2.40G/3.50G [00:19<00:04, 249MB/s]
# pytorch_model-00002-of-00002.bin:  69% 2.43G/3.50G [00:19<00:04, 236MB/s]
# pytorch_model-00002-of-00002.bin:  71% 2.47G/3.50G [00:19<00:03, 263MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.51G/3.50G [00:19<00:03, 275MB/s]
# pytorch_model-00002-of-00002.bin:  72% 2.54G/3.50G [00:19<00:03, 260MB/s]
# pytorch_model-00002-of-00002.bin:  73% 2.57G/3.50G [00:19<00:03, 261MB/s]
# pytorch_model-00002-of-00002.bin:  74% 2.60G/3.50G [00:20<00:03, 254MB/s]
# pytorch_model-00002-of-00002.bin:  75% 2.64G/3.50G [00:20<00:03, 251MB/s]
# pytorch_model-00002-of-00002.bin:  76% 2.67G/3.50G [00:20<00:03, 257MB/s]
# pytorch_model-00002-of-00002.bin:  77% 2.71G/3.50G [00:20<00:02, 268MB/s]
# pytorch_model-00002-of-00002.bin:  78% 2.74G/3.50G [00:20<00:02, 256MB/s]
# pytorch_model-00002-of-00002.bin:  79% 2.78G/3.50G [00:20<00:02, 280MB/s]
# pytorch_model-00002-of-00002.bin:  81% 2.82G/3.50G [00:20<00:02, 307MB/s]
# pytorch_model-00002-of-00002.bin:  81% 2.85G/3.50G [00:20<00:02, 270MB/s]
# pytorch_model-00002-of-00002.bin:  83% 2.89G/3.50G [00:21<00:02, 290MB/s]
# pytorch_model-00002-of-00002.bin:  84% 2.94G/3.50G [00:21<00:01, 284MB/s]
# pytorch_model-00002-of-00002.bin:  85% 2.97G/3.50G [00:21<00:02, 260MB/s]
# pytorch_model-00002-of-00002.bin:  86% 3.00G/3.50G [00:21<00:01, 260MB/s]
# pytorch_model-00002-of-00002.bin:  87% 3.03G/3.50G [00:21<00:02, 221MB/s]
# pytorch_model-00002-of-00002.bin:  88% 3.07G/3.50G [00:21<00:01, 246MB/s]
# pytorch_model-00002-of-00002.bin:  89% 3.11G/3.50G [00:21<00:01, 278MB/s]
# pytorch_model-00002-of-00002.bin:  90% 3.15G/3.50G [00:22<00:01, 267MB/s]
# pytorch_model-00002-of-00002.bin:  91% 3.18G/3.50G [00:22<00:01, 261MB/s]
# pytorch_model-00002-of-00002.bin:  92% 3.21G/3.50G [00:22<00:01, 244MB/s]
# pytorch_model-00002-of-00002.bin:  93% 3.24G/3.50G [00:22<00:01, 253MB/s]
# pytorch_model-00002-of-00002.bin:  94% 3.28G/3.50G [00:22<00:00, 294MB/s]
# pytorch_model-00002-of-00002.bin:  95% 3.31G/3.50G [00:22<00:00, 237MB/s]
# pytorch_model-00002-of-00002.bin:  96% 3.36G/3.50G [00:22<00:00, 272MB/s]
# pytorch_model-00002-of-00002.bin:  97% 3.39G/3.50G [00:23<00:00, 224MB/s]
# pytorch_model-00002-of-00002.bin:  98% 3.42G/3.50G [00:23<00:00, 216MB/s]
# pytorch_model-00002-of-00002.bin:  99% 3.45G/3.50G [00:23<00:00, 232MB/s]
# pytorch_model-00002-of-00002.bin: 100% 3.50G/3.50G [00:23<00:00, 149MB/s]
# Downloading shards: 100% 2/2 [01:15<00:00, 37.59s/it]
# Loading checkpoint shards: 100% 2/2 [01:04<00:00, 32.02s/it]
# generation_config.json: 100% 162/162 [00:00<00:00, 1.07MB/s]
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`. This was detected when initializing the generation config instance, which means the corresponding file may hold incorrect parameterization and should be fixed.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# tokenizer_config.json: 100% 749/749 [00:00<00:00, 4.12MB/s]
# tokenizer.model: 100% 500k/500k [00:00<00:00, 351MB/s]
# special_tokens_map.json: 100% 438/438 [00:00<00:00, 3.37MB/s]
# 2024-07-05 06:25:24 - Created default chainlit markdown file at /content/chainlit.md
# 2024-07-05 06:25:24 - Your app is available at http://localhost:8000
# 2024-07-05 06:25:48 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:25:49 - Translated markdown file for vi not found. Defaulting to chainlit.md.
# 2024-07-05 06:26:00 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:26:15 - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:515: UserWarning: `do_sample` is set to `False`. However, `temperature` is set to `0.9` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `temperature`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:520: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.6` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# 2024-07-05 06:27:01 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:27:40 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:28:08 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:28:26 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:28:34 - Translation file for vi not found. Using default translation en-US.
# 2024-07-05 06:29:10 - Translation file for vi not found. Using default translation en-US.
